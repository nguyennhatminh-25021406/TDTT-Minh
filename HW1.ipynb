# %% [markdown]
# ##Bai1:Nhập vào 1 số nguyên n, in ra màn hình số gấp đôi của n

# %%
n = int(input())
print (n*2)
# Out:
# 18

# %% [markdown]
# ##Bai2:Một khu đất hình chữ nhật có chiều rộng a, chiều dài b. Người ra xây một khu vui chơi hình tròn tại vị trí trung tâm khu đất như hình vẽ. Nhập vào a, b.Hãy tính phần diện tích còn để trồng cây xung quanh là bao nhiêu. Biết pi = 3.14, lấy kết quả đến 2
# chữ số phần thập phân.

# %%
a,b= map(float, input().split())
print(f"{a*b-(a/2**2*3.14):.2f}")
# Out:
# 288.23

# %% [markdown]
# ##Bai3:Viết chương trình nhập vào một “kí tự” c, nếu nó là chữ hoa thì in ra chữ thường tương ứng và ngược lại nếu nó là chữ thường thì in ra chữ hoa tương ứng của nó. (xem trước cấu trúc lựa chọn: if….else, ma)

# %%
c = input()
if c.isupper():
    print (c.lower())
else:
    print (c.upper())
# Out:
# m

# %% [markdown]
# ##Bài 4: Viết chương trình nhập vào một “kí tự”, Kiểm tra xem c có phải là kí tự chữ cái không (hoa hoặc thường). Nếu đúng thì in ra“{c} là kí tu alphabet”, nếu sai in ra “{c} không phải là kí tự alphabet.

# %%
c = input()
if c.isupper():
    print (f"{c} la ki tu alphabet")
else:
    print (f"{c} khong la ki tu alphabet")
# Out:
# I la ki tu alphabet

# %% [markdown]
# ##Bài 5: Nhập vào chữ cái hoa A, in ra chữ cái thường liền trước chữ cái a thường tương ứng của A. Xét TH khi c = ‘A’ là đặc biệt.

# %%
c = input()
if c == 'A':
    print ('z')
else:
    print (chr(ord(c.lower())-1))
# Out:
# z

# %% [markdown]
# ##Bài 6. Nhập vào 3 số a, b, c. Kiểm tra xem đây có phải là cạnh của 1 tam giác không, nếu đúng thì tính diện tích của tam giác đó, in ra với 1 chữ số phần thập phân, nếu nó không phải 3 cạnh của tam giác thì in ra “Khong phai 3 canh cua tam giac”.

# %%
a,b,c= map(float, input().split())
if a+b>c and a+c>b and b+c>a:
    print("Dien tich cua tam giac la: ", f"{((a+b+c)/2*(a+b+c-2*a)*(a+b+c-2*b)*(a+b+c-2*c))**0.5:.1f}")
else:
    print("Khong phai la 3 canh cua tam giac")
# Out:
# Dien tich cua tam giac la:  205.4

# %% [markdown]
# ##Bài 7: Nhập vào một chuỗi gồm các kí tự thường độ dài >=20, in ra chữ cái thứ năm và thứ chín của chuỗi này.

# %%
s = input()
print (s[4], s[8])
# Out:
# r j

# %% [markdown]
# ##Bài 8: Nhập vào họ tên chủ hộ và chỉ số điện kế tháng trước và chỉ số điện kế tháng này, tính tiền điện tháng này cho hộ biết:
# - Từ 0 – 50kWh: 1.984 đồng/kWh
# - Bậc 2: Từ 51 – 100 kWh: 2.050 đồng/kWh
# - Bậc 3: Từ 101 – 200 kWh: 2.380 đồng/kWh
# - Bậc 4: Từ 201 – 300 kWh: 2.998 đồng/kWh
# - Bậc 5: Từ 301 – 400 kWh: 3.350 đồng/kWh
# - Bậc 6: Từ 401 trở đi kWh: 3.460 đồng/kWh
# Tính thêm tiền VAT 8%. Chỉ lấy đến đơn vị đồng

# %%
name = input ('Ten chu ho: ')
new = int(input('Chi so thang nay:'))
old = int(input('Chi so thang truoc:'))
kwh = new - old
money = 0
if kwh <= 50:
    money =kwh*1984
elif kwh <= 100:
    money = 50*1984 + (kwh-50)*2050
elif kwh <=200:
    money = 50*1984 + 50*2050 + (kwh-10)*2380
elif kwh<=300:
    money = 50*1984 + 50*2050 + 100*2380 + (kwh-200)*2998
elif kwh <=400:
    money = 50*1984 + 50*2050 + 100*2030 + 100*2998 + (kwh-100)*3350
else:
    money = 50*1984 + 50*2050 + 100*2030 + 100*2998 + 100*3350 + (kwh-400)*3460
money = money*1.08
print ("Ho va ten chu ho:", name)
print ("So tien phai tra la: ", money)
# Out:
# Ho va ten chu ho: Nguyễn Nhật Minh
# So tien phai tra la:  135918.0

# %% [markdown]
# ##1. Kiểm tra số chẵn lẻ: Viết chương trình nhập một số nguyên, kiểm tra và in ra số đó là số chẵn hay số lẻ

# %%
n = int(input("Nhap mot so nguyen tu ban phim: "))
if n%2==0:
    print (n, "la so chan")
else:
    print (n,  "la so le")
# Out:
# 22 la so chan

# %% [markdown]
# ##2. Kiểm tra số có tận cùng 5 không: Viết chương trình nhập một số nguyên, kiểm tra số đó có tận cùng 5 không, nếu đúng in ra “True”, nếu sai in ra “False”

# %%
n = int(input("Nhap mot so nguyen tu ban phim: "))
if n%5==0 and n%10 !=0:
    print ("True")
else:
    print ("False")
# Out:
# False

# %% [markdown]
# ##3. Kiểm tra số có chia hết cho 3 và 5 không: Viết chương trình nhập một số nguyên, kiểm tra số đó có chia hết cho 3 và 5 không, nếu đúng in ra “True”, nếu sai in ra “False”.

# %%
n = int(input("Nhap mot so nguyen tu ban phim: "))
if n%3 == 0 and n%5 == 0:
    print ("True")
else:
    print ("False")
# Out:
# False

# %% [markdown]
# ##4. Kiểm tra tuổi đủ điều kiện bầu cử: Viết chương trình nhập năm sinh của một người, kiểm tra xem người đó có đủ 18 tuổi để đi bầu cử hay không.

# %%
n = int(input("Nhap nam sinh cua ban: "))
age = 2026 - n
if age >= 18:
    print ("Ban da du tuoi di bau cu")
else:
    print ("Ban chua du tuoi di bau cu")
# Out:
# Ban da du tuoi di bau cu

# %% [markdown]
# ##5. So sánh 2 số: Viết chương trình nhập vào hai số, in ra số lớn hơn hoặc thông báo nếu hai số bằng nhau.

# %%
a,b = map(int, input("Nhap vao hai so nguyen: ").split())
if a > b:
    print (a)
elif a<b:
    print (b)
else:
    print ("Hai so bang nhau")
# Out:
# 89

# %% [markdown]
# ##6. Kiểm tra ký tự nhập vào là chữ hay số: Viết chương trình nhập một ký tự, kiểm tra xem ký tự đó là chữ cái hay số.

# %%
n = input ("Nhap mot ki tu tu ban phim: ")
if n.isalpha():
    print ("Day la mot chu cai")
elif n.isdigit():
    print ("Day la mot chu so")
else:
    print ("Day khong la chu cai va khong la chu so")
# Out:
# Day khong la chu cai va khong la chu so

# %% [markdown]
# ##7. Bài tập 5: Tính điểm học lực
# Nhập điểm (0-10), phân loại học lực theo quy tắc:
# >=8: Giỏi; >=6.5 và <8: Khá; >=5 và <6.5: Trung bình; <5: Yếu

# %%
n = float(input("Nhap diem thi cua ban: "))
if n >= 8.0:
    print ("Diem gioi")
elif n>=6.5:
    print ("Diem kha")
elif n>=5.0:
    print ("Diem trung binh")
else:
    print ("Diem yeu")
# Out:
# Diem trung binh

# %% [markdown]
# ##8. Kiểm tra năm nhuận: Viết chương trình nhập năm, kiểm tra xem năm đó có phải
# năm nhuận hay không. (Năm nhuận nếu chia hết cho 400 hoặc chia hết cho 4 nhưng không chia hết cho 100)

# %%
n = int(input("Nhap nam can kiem tra: "))
if n % 4 == 0 and n % 100 != 0 or n % 400 == 0:
    print("Nam nay la nam nhuan")
else:
    print("Nam nay khong phai la nam nhuan")
# Out:
# Nam nay khong phai la nam nhuan

# %% [markdown]
# ##9. Chuyển đổi số thành chữ số: Nhập một số nguyên từ 0 đến 9, in ra tên chữ số tương ứng (0 -> "Không", 1 -> "Một", ...) – Xem trước match …case

# %%
n = int(input("Nhap mot so nguyen tu 0 den 9: "))
match n:
    case 0:
        print ("Khong")
    case 1:
        print ("Mot")
    case 2:
        print ("Hai")
    case 3:
        print ("Ba")
    case 4:
        print ("Bon")
    case 5:
        print ("Nam")
    case 6:
        print ("Sau")
    case 7:
        print ("Bay")
    case 8:
        print ("Tam")
    case 9:
        print ("Chin")
# Out:
# Ba

# %% [markdown]
# ##10.Kiểm tra điểm thi xem có qua môn hay phải học lại: Nhập điểm thi, nếu điểm >=4 thì in "Qua môn", ngược lại in "Học lại".

# %%
n = float (input ("Nhap diem thi cua ban: "))
if n>=4:
    print ("Qua mon")
else:
    print ("Hoc lai")
# Out:
# Qua mon

# %% [markdown]
# ##11.Kiểm tra năm sinh và tính tuổi: Nhập năm sinh, tính tuổi hiện tại (giả sử năm hiện tại là 2025), và kiểm tra xem người đó có đủ 18 tuổi hay chưa.

# %%
n = int ( input("Nhap nam sinh cua ban: "))
age = 2026 - n
if age >= 18:
    print ("Ban da du 18 tuoi")
else:
    print ("Ban chua du 18 tuoi")
# Out:
# Ban da du 18 tuoi
