# %% [markdown]
# #W6A1-Nhập vào một dòng gồm các số nguyên. Hãy loại bỏ phần tử trùng nhưng giữ nguyên thứ tự xuất hiện đầu tiên, rồi in ra list kết quả.
# Yêu cầu in ra đúng dạng list Python, ví dụ [1, 2, 3]

# %%
nums = list(map(int, input().split()))
result = []
for i in nums:
    if i not in result:
        result.append(i)
print(result)
# Out:
# [1, 2, 4, 3]

# %% [markdown]
# #W6A2 Nhập một dòng số nguyên. In ra list tổng tích lũy (phần tử i là tổng từ đầu tới vị trí i), giữ nguyên thứ tự

# %%
nums = list(map(int, input().split()))
result = []
s = 0
for i in nums:
    s += i
    result.append(s)
print(result)
# Out:
# [1, 3, 6, 10, 12, 15, 19, 21, 22]

# %% [markdown]
# #W6A3 Nhập một tuple số nguyên (một dòng) và số nguyên k (dòng kế). In ra tuple sau khi xoay trái k vị trí. (Giữ nguyên thứ tự tương đối sau xoay; không sắp xếp.)

# %%
nums = tuple(map(int, input().split()))
k = int(input())
n = len(nums)
k = k % n
result = nums[-k:] + nums[:-k]
print(result)
# Out:
# (5, 2, 4, 1, 3, 4, 3, 2, 2)

# %% [markdown]
# #W6A4 Nhập một dòng gồm các cặp key:value cách nhau bởi dấu cách. Tạo dictionary ánh xạ mỗi key -> list các value theo thứ tự xuất hiện. Nếu key lặp lại, thêm vào list của key đó

# %%
a = input().split()
dict = {}
for i in a:
    key, value = i.split(':')
    if key in dict:
        dict[key].append(value)
    else:
        dict[key] = [value]
print(dict)
# Out:
# {'a': ['2'], 'b': ['2'], 'c': ['4']}

# %% [markdown]
# #W6A5 Nhập một list số nguyên, In ra dictionary {'positives': ..., 'negatives': ..., 'zeros': ...} (đếm số >0, <0, =0)

# %%
nums = list(map(int, input().split()))
dict = {}
for i in nums:
    if  i > 0:
        dict[i] = 'positive'
    elif i < 0:
        dict[i] = 'negative'
    else:
        dict[i] = 'zero'
print(dict)
# Out:
# {3: 'positive', 4: 'positive', 6: 'positive', -3: 'negative', -4: 'negative', 0: 'zero'}

# %% [markdown]
# #W6A6 Viết chương trình nhập vào một danh sách các số nguyên, sau đó in ra tổng các số trong list đó.

# %%
nums = list(map(int, input().split()))
s = 0
for i in nums:
    s += i
print(s)
# Out:
# 16

# %% [markdown]
# #W6A7 Viết chương trình nhập vào một tuple, in ra phần tử đầu, phần tử cuối, và tuple đảo ngược

# %%
nums = tuple(map(int, input().split()))
print(nums[::-1])
print(nums[0])
print(nums[-1])
# Out:
# (4, 3, 2, 1)
# 1
# 4

# %% [markdown]
# #W6A8 Viết chương trình nhập vào một list các chuỗi, sau đó đếm số lần xuất hiện của từng chuỗi và lưu vào dictionary

# %%
chuoi = list(input().split())
count = {}
for i in chuoi:
    if i in count:
        count[i] += 1
    else:
        count[i] = 1
print(count)
# Out:
# {'cam': 1, 'chuoi': 1, 'mit': 1}

# %% [markdown]
# #W6A9 Viết chương trình nhập vào hai dictionary. Sau đó gộp lại thành một dictionary mới trong đó nếu một key xuất hiện trong cả hai dict, giá trị sẽ được cộng lại, nếu chỉ có trong một dict thì giữ nguyên. In ra dictionary mới theo thứ tự từ điển tăng dần của key.

# %%
dict1 = eval(input("Nhap dictionary thua nhat: "))
dict2 = eval(input("Nhap dictionary thua hai: "))
#gop 2 dict
new_dict = dict1.copy()
for key, value in dict2.items():
    if key in new_dict:
        new_dict[key] += value
    else:
        new_dict[key] = value
sorted_dict = dict(sorted(new_dict.items()))
print(sorted_dict)
# Out:
# {'a': 6, 'b': 7, 'c': 10}

# %% [markdown]
# #W6A10 Viết chương trình nhập vào một danh sách các số nguyên, và số nguyên dương k. In ra list gồm các cặp số khác nhau có tổng bằng k. Mỗi cặp là một tuple, hai số trong tuple có thể giống nhau, thứ tự xuất hiện trong danh sách của số thứ nhất nhỏ hơn thứ tự của số thứ hai. Các tuple trong list được sắp xếp theo thứ tự tăng dần của phần tử đầu tiên trong tuple.

# %%
nums = list(map(int, input().split()))
k = int(input())
result = [[i,j] for i in nums for j in nums if i + j == k]
print(result)
# Out:
# [[5, 5], [5, 5], [5, 5], [5, 5]]

# %% [markdown]
# #W6A11 [Tách số chẵn và lẻ từ tuple] Nhập vào một tuple chứa các số nguyên. Hãy tạo ra hai tuple mới: một chứa tất cả các số chẵn và một chứa tất cả các số lẻ từ tuple ban đầu, giữ nguyên thứ tự tương đối. In ra hai tuple này trên hai dòng riêng biệt.

# %%
tup = tuple(map(int, input().split()))
tup1 = []
tup2 = []
for i in tup:
    if i % 2 == 0:
        tup1.append(i)
    else:
        tup2.append(i) 
print(tuple(tup1))
print(tuple(tup2))
# Out:
# (2, 8)
# (3, 5, 5, 3, 5, 7, 5)

# %% [markdown]
# #W6A12 [Tìm phần tử xuất hiện nhiều nhất] Nhập vào một list các số nguyên. Hãy tìm số xuất hiện nhiều lần nhất trong list. Nếu có nhiều số cùng có số lần xuất hiện nhiều nhất, hãy in ra số nhỏ
# nhất trong số đó.

# %%
nums = list(map(int, input().split()))
max_count = 0
result = nums[0]
for i in nums:
    count = nums.count(i)
    if count > max_count:
        max_count = count
        result = i
    elif count == max_count:
        result = min(result, i)
print(result)
# Out:
# 3

# %% [markdown]
# ##W6A13 [Đảo ngược key và value của dictionary] Nhập vào một dictionary có value là duy nhất (không trùng nhau). Hãy tạo một dictionary mới bằng cách đảo ngược key và value của dictionary ban
# đầu. In ra dictionary mới.

# %%
x = eval(input())
y = {}
for key, value in x.items():
    y[value] = key
print(y)
# Out:
# {7: 'a', 9: 'b'}

# %% [markdown]
# #W6A14 [Giao của hai danh sách] Nhập vào hai dòng, mỗi dòng là một danh sách các số nguyên. Hãy tìm các
# phần tử chung (giao) của hai danh sách này và in ra một list mới chứa các phần tử chung đó, không trùng lặp.

# %%
x = list(map(int, input().split()))
y =list(map(int, input().split()))
a = []
for i in x:
    if i in y and i not in a:
        a.append(i)
print (a)
# Out:
# [2, 3]

# %% [markdown]
# #W6A15 [Lọc dictionary theo giá trị] Nhập vào một dictionary có key là chuỗi và value là số nguyên, và một số nguyên k ở dòng tiếp theo. Hãy tạo một dictionary mới chỉ chứa các cặp key-value từ dictionary ban đầu mà có value lớn hơn k. In ra dictionary mới.

# %%
dict = eval(input())
k = int(input())
dict_new = {}
for key, value in dict.items():
    if value > k:
        dict_new[key] = value
print(dict_new)
# Out:
# {'b': 25, 'c': 9}
